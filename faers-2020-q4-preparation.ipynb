# %% [markdown]
# # What is FAERS?
# The FDA Adverse Event Reporting System (FAERS) is a database that contains adverse event reports, medication error reports and product quality complaints resulting in adverse events that were submitted to FDA. The database is designed to support the FDA's post-marketing safety surveillance program for drug and therapeutic biologic products.
# https://www.fda.gov/drugs/surveillance/questions-and-answers-fdas-adverse-event-reporting-system-faers

# %%
import numpy as np
import pandas as pd

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))
# Out:
# /kaggle/input/faers2020/DRUG20Q4.txt
# /kaggle/input/faers2020/OUTC20Q4.txt
# /kaggle/input/faers2020/DEMO20Q4.txt
# /kaggle/input/faers2020/INDI20Q4.txt
# /kaggle/input/faers2020/RPSR20Q4.txt
# /kaggle/input/faers2020/REAC20Q4.txt
# /kaggle/input/faers2020/THER20Q4.txt

# %%
demo0 = open('../input/faers2020/DEMO20Q4.txt', 'r')
demo1 = demo0.read()
demo2 = demo1.split('\n')
demo3=[]
for item in demo2:
    demo3+=[item.split('$')]
demo4=pd.DataFrame(demo3[1:],columns=demo3[0])
print(demo4[0:1].T)
# Out:
#                                          0
# primaryid                        100046573
# caseid                            10004657
# caseversion                              3
# i_f_code                                 F
# event_dt                          20120731
# mfr_dt                            20201030
# init_fda_dt                       20140312
# fda_dt                            20201103
# rept_cod                               EXP
# auth_num
# mfr_num           US-PFIZER INC-2014065269
# mfr_sndr                            PFIZER
# lit_ref
# age                                     71
# age_cod                                 YR
# age_grp
# sex                                      F
# e_sub                                    Y
# wt                                   81.63
# wt_cod                                  KG
# rept_dt                           20201103
# to_mfr
# occp_cod                                LW
# reporter_country                        US
# ...

# %%
drug0 = open('../input/faers2020/DRUG20Q4.txt', 'r')
drug1 = drug0.read()
drug2 = drug1.split('\n')
drug3=[]
for item in drug2:
    drug3+=[item.split('$')]
drug4=pd.DataFrame(drug3[1:],columns=drug3[0])
print(drug4[0:1].T)
# Out:
#                                   0
# primaryid                 100046573
# caseid                     10004657
# drug_seq                          1
# role_cod                         PS
# drugname                    LIPITOR
# prod_ai        ATORVASTATIN CALCIUM
# val_vbm                           1
# route                          Oral
# dose_vbm                 40 MG, UNK
# cum_dose_chr
# cum_dose_unit
# dechal                            D
# rechal
# lot_num
# exp_dt
# nda_num                      020702
# dose_amt                         40
# dose_unit                        MG
# dose_form        FILM-COATED TABLET
# dose_freq

# %%
indi0 = open('../input/faers2020/INDI20Q4.txt', 'r')
indi1 = indi0.read()
indi2 = indi1.split('\n')
indi3=[]
for item in indi2:
    indi3+=[item.split('$')]
indi4=pd.DataFrame(indi3[1:],columns=indi3[0])
print(indi4[0:1].T)
# Out:
#                                                0
# primaryid                              100046573
# caseid                                  10004657
# indi_drug_seq                                  1
# indi_pt        Low density lipoprotein increased

# %%
outc0 = open('../input/faers2020/OUTC20Q4.txt', 'r')
outc1 = outc0.read()
outc2 = outc1.split('\n')
outc3=[]
for item in outc2:
    outc3+=[item.split('$')]
outc4=pd.DataFrame(outc3[1:],columns=outc3[0])
print(outc4[0:1].T)
# Out:
#                    0
# primaryid  100046573
# caseid      10004657
# outc_cod          OT

# %%
reac0 = open('../input/faers2020/REAC20Q4.txt', 'r')
reac1 = reac0.read()
reac2 = reac1.split('\n')
reac3=[]
for item in reac2:
    reac3+=[item.split('$')]
reac4=pd.DataFrame(reac3[1:],columns=reac3[0])
print(reac4[0:1].T)
# Out:
#                                      0
# primaryid                    100046573
# caseid                        10004657
# pt            Type 2 diabetes mellitus
# drug_rec_act

# %%
rpsr0 = open('../input/faers2020/RPSR20Q4.txt', 'r')
rpsr1 = rpsr0.read()
rpsr2 = rpsr1.split('\n')
rpsr3=[]
for item in rpsr2:
    rpsr3+=[item.split('$')]
rpsr4=pd.DataFrame(rpsr3[1:],columns=rpsr3[0])
print(rpsr4[0:1].T)
# Out:
#                    0
# primaryid  183341011
# caseid      18334101
# rpsr_cod         CSM

# %%
ther0 = open('../input/faers2020/THER20Q4.txt', 'r')
ther1 = ther0.read()
ther2 = ther1.split('\n')
ther3=[]
for item in ther2:
    ther3+=[item.split('$')]
ther4=pd.DataFrame(ther3[1:],columns=ther3[0])
print(ther4[0:1].T)
# Out:
#                       0
# primaryid     100046573
# caseid         10004657
# dsg_drug_seq          1
# start_dt       20090217
# end_dt         20110901
# dur
# dur_cod

# %%
print(demo4.info())
demo4.to_csv('demo20q4.csv',index=False)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 436149 entries, 0 to 436148
# Data columns (total 25 columns):
#  #   Column            Non-Null Count   Dtype
# ---  ------            --------------   -----
#  0   primaryid         436149 non-null  object
#  1   caseid            436148 non-null  object
#  2   caseversion       436148 non-null  object
#  3   i_f_code          436148 non-null  object
#  4   event_dt          436148 non-null  object
#  5   mfr_dt            436148 non-null  object
#  6   init_fda_dt       436148 non-null  object
#  7   fda_dt            436148 non-null  object
#  8   rept_cod          436148 non-null  object
#  9   auth_num          436148 non-null  object
#  10  mfr_num           436148 non-null  object
#  11  mfr_sndr          436148 non-null  object
#  12  lit_ref           436148 non-null  object
#  13  age               436148 non-null  object
#  14  age_cod           436148 non-null  object
#  15  age_grp           436148 non-null  object
# ...

# %%
print(drug4.info())
drug4.to_csv('drug20q4.csv',index=False)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1918928 entries, 0 to 1918927
# Data columns (total 20 columns):
#  #   Column         Dtype
# ---  ------         -----
#  0   primaryid      object
#  1   caseid         object
#  2   drug_seq       object
#  3   role_cod       object
#  4   drugname       object
#  5   prod_ai        object
#  6   val_vbm        object
#  7   route          object
#  8   dose_vbm       object
#  9   cum_dose_chr   object
#  10  cum_dose_unit  object
#  11  dechal         object
#  12  rechal         object
#  13  lot_num        object
#  14  exp_dt         object
#  15  nda_num        object
#  16  dose_amt       object
#  17  dose_unit      object
#  18  dose_form      object
#  19  dose_freq      object
# dtypes: object(20)
# memory usage: 292.8+ MB
# None

# %%
print(indi4.info())
indi4.to_csv('indi20q4.csv',index=False)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1297447 entries, 0 to 1297446
# Data columns (total 4 columns):
#  #   Column         Non-Null Count    Dtype
# ---  ------         --------------    -----
#  0   primaryid      1297447 non-null  object
#  1   caseid         1297446 non-null  object
#  2   indi_drug_seq  1297446 non-null  object
#  3   indi_pt        1297446 non-null  object
# dtypes: object(4)
# memory usage: 39.6+ MB
# None

# %%
print(outc4.info())
outc4.to_csv('outc20q4.csv',index=False)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 365576 entries, 0 to 365575
# Data columns (total 3 columns):
#  #   Column     Non-Null Count   Dtype
# ---  ------     --------------   -----
#  0   primaryid  365576 non-null  object
#  1   caseid     365575 non-null  object
#  2   outc_cod   365575 non-null  object
# dtypes: object(3)
# memory usage: 8.4+ MB
# None

# %%
print(reac4.info())
reac4.to_csv('reac20q4.csv',index=False)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1522658 entries, 0 to 1522657
# Data columns (total 4 columns):
#  #   Column        Non-Null Count    Dtype
# ---  ------        --------------    -----
#  0   primaryid     1522658 non-null  object
#  1   caseid        1522657 non-null  object
#  2   pt            1522657 non-null  object
#  3   drug_rec_act  1522657 non-null  object
# dtypes: object(4)
# memory usage: 46.5+ MB
# None

# %%
print(rpsr4.info())
rpsr4.to_csv('rpsr20q4.csv',index=False)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 14478 entries, 0 to 14477
# Data columns (total 3 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   primaryid  14478 non-null  object
#  1   caseid     14477 non-null  object
#  2   rpsr_cod   14477 non-null  object
# dtypes: object(3)
# memory usage: 339.5+ KB
# None

# %%
print(ther4.info())
ther4.to_csv('ther20q4.csv',index=False)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 681412 entries, 0 to 681411
# Data columns (total 7 columns):
#  #   Column        Non-Null Count   Dtype
# ---  ------        --------------   -----
#  0   primaryid     681412 non-null  object
#  1   caseid        681411 non-null  object
#  2   dsg_drug_seq  681411 non-null  object
#  3   start_dt      681411 non-null  object
#  4   end_dt        681411 non-null  object
#  5   dur           681411 non-null  object
#  6   dur_cod       681411 non-null  object
# dtypes: object(7)
# memory usage: 36.4+ MB
# None

# %% [markdown]
# ### What do you do next?
